# %% [markdown]
# # Sequence Models
# Inspect sequence, batch, feature, and hidden-state shapes in an RNN.

# %%
import torch
torch.manual_seed(42)
X = torch.randn(4, 7, 12)
rnn = torch.nn.RNN(12, 20, batch_first=True)
outputs, hidden = rnn(X)
print('outputs:', outputs.shape, 'hidden:', hidden.shape)
