# %% [markdown]
# # Deep Learning Foundations
# Trace batch, feature, and output shapes before training a dense layer.

# %%
import torch
torch.manual_seed(42)
X = torch.randn(32, 10)
layer = torch.nn.Linear(10, 5)
y = layer(X)
print('X:', X.shape, 'W:', layer.weight.shape, 'y:', y.shape)
